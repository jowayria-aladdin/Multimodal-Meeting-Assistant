# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("waseemnagahhenes/sign-language-dataset-wlasl-videos")

print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.13)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 import kagglehub
#       3 # Download latest version
# ----> 4 path = kagglehub.dataset_download("waseemnagahhenes/sign-language-dataset-wlasl-videos")
#       6 print("Path to dataset files:", path)
#
# File c:\Users\adham\AppData\Local\Programs\Python\Python312\Lib\site-packages\kagglehub\datasets.py:28, in dataset_download(handle, path, force_download)
#      26 h = parse_dataset_handle(handle)
#      27 logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 28 return registry.dataset_resolver(h, path, force_download=force_download)
#
# File c:\Users\adham\AppData\Local\Programs\Python\Python312\Lib\site-packages\kagglehub\registry.py:23, in MultiImplRegistry.__call__(self, *args, **kwargs)
#      21 for impl in reversed(self._impls):
#      22     if impl.is_supported(*args, **kwargs):
# ---> 23         return impl(*args, **kwargs)
#      24     else:
#      25         fails.append(type(impl).__name__)
#
# File c:\Users\adham\AppData\Local\Programs\Python\Python312\Lib\site-packages\kagglehub\http_resolver.py:125, in DatasetHttpResolver.__call__(self, h, path, force_download)
#     122 os.makedirs(os.path.dirname(archive_path), exist_ok=True)
#     124 # First, we download the archive.
# --> 125 api_client.download_file(url_path, archive_path, h)
#     127 # Create the directory to extract the archive to.
#     128 os.makedirs(out_path, exist_ok=True)
#
# File c:\Users\adham\AppData\Local\Programs\Python\Python312\Lib\site-packages\kagglehub\clients.py:152, in KaggleApiV1Client.download_file(self, path, out_file, resource_handle, cached_path)
#     142 """
#     143 Issues a call to kaggle api and downloads files. For competition downloads,
#     144 call may return early if local cache is newer than the last time the file was modified.
#    (...)
#     147 bool:  If downloading remote was necessary
#     148 """
#     149 url = self._build_url(path)
#     150 with requests.get(
#     151     url,
# --> 152     headers={"User-Agent": get_user_agent()},
#     153     stream=True,
#     154     auth=self._get_auth(),
#     155     timeout=(DEFAULT_CONNECT_TIMEOUT, DEFAULT_READ_TIMEOUT),
#     156 ) as response:
#     157     kaggle_api_raise_for_status(response, resource_handle)
#     158     total_size = int(response.headers["Content-Length"])
#
# File c:\Users\adham\AppData\Local\Programs\Python\Python312\Lib\site-packages\kagglehub\clients.py:70, in get_user_agent()
#      67 user_agents = [f"kagglehub/{kagglehub.__version__}"]
#      69 for keras_lib in ("keras_hub", "keras_nlp", "keras_cv", "keras"):
# ---> 70     keras_info = search_lib_in_call_stack(keras_lib)
#      71     if keras_info is not None:
#      72         user_agents.append(keras_info)
#
# File c:\Users\adham\AppData\Local\Programs\Python\Python312\Lib\site-packages\kagglehub\env.py:54, in search_lib_in_call_stack(lib_name)
#      43 def search_lib_in_call_stack(lib_name: str) -> Optional[str]:
#      44     """Search the call stack for a given library name and get its information.
#      45
#      46     Args:
#    (...)
#      52         str: A formatted string f"{lib_name}/{lib_version}" if found, otherwise None.
#      53     """
# ---> 54     for frame_info in inspect.stack():
#      55         module = inspect.getmodule(frame_info.frame)
#      56         if module and hasattr(module, "__name__"):
#
# File c:\Users\adham\AppData\Local\Programs\Python\Python312\Lib\inspect.py:1774, in stack(context)
#    1772 def stack(context=1):
#    1773     """Return a list of records for the stack above the caller's frame."""
# -> 1774     return getouterframes(sys._getframe(1), context)
#
# File c:\Users\adham\AppData\Local\Programs\Python\Python312\Lib\inspect.py:1749, in getouterframes(frame, context)
#    1747 framelist = []
#    1748 while frame:
# -> 1749     traceback_info = getframeinfo(frame, context)
#    1750     frameinfo = (frame,) + traceback_info
#    1751     framelist.append(FrameInfo(*frameinfo, positions=traceback_info.positions))
#
# File c:\Users\adham\AppData\Local\Programs\Python\Python312\Lib\inspect.py:1711, in getframeinfo(frame, context)
#    1709 start = lineno - 1 - context//2
#    1710 try:
# -> 1711     lines, lnum = findsource(frame)
#    1712 except OSError:
#    1713     lines = index = None
#
# File c:\Users\adham\AppData\Local\Programs\Python\Python312\Lib\inspect.py:1075, in findsource(object)
#    1067 def findsource(object):
#    1068     """Return the entire source file and starting line number for an object.
#    1069
#    1070     The argument may be a module, class, method, function, traceback, frame,
#    1071     or code object.  The source code is returned as a list of all the lines
#    1072     in the file and the line number indexes a line in that list.  An OSError
#    1073     is raised if the source code cannot be retrieved."""
# -> 1075     file = getsourcefile(object)
#    1076     if file:
#    1077         # Invalidate cache if needed.
#    1078         linecache.checkcache(file)
#
# File c:\Users\adham\AppData\Local\Programs\Python\Python312\Lib\inspect.py:967, in getsourcefile(object)
#     965     return filename
#     966 # only return a non-existent filename if the module has a PEP 302 loader
# --> 967 module = getmodule(object, filename)
#     968 if getattr(module, '__loader__', None) is not None:
#     969     return filename
#
# File c:\Users\adham\AppData\Local\Programs\Python\Python312\Lib\inspect.py:1006, in getmodule(object, _filename)
#    1004 if ismodule(module) and hasattr(module, '__file__'):
#    1005     f = module.__file__
# -> 1006     if f == _filesbymodname.get(modname, None):
#    1007         # Have already mapped this module, so skip it
#    1008         continue
#    1009     _filesbymodname[modname] = f
#
# KeyboardInterrupt:
